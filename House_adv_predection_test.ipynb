# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline

# %%
df_train =pd.read_csv('/content/house_adv_train.csv')
df_test =pd.read_csv('/content/house_adv_test.csv')
df_submission =pd.read_csv('/content/house_adv_submission.csv')

# %%
print('Shape train_set :',df_train.shape)
print('Shape test_set :',df_test.shape)
# Out:
# Shape train_set : (1460, 81)
# Shape test_set : (1459, 80)

# %%
df_train.head(4)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
#
# [4 rows x 81 columns]

# %% [markdown]
# # *COLUMNS DETAILS:*

# %% [markdown]
# Data fields
#
# Here's a brief version of what you'll find in the data description file.
#
# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# MSSubClass: The building class
#
# MSZoning: The general zoning classification
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access
#
# Alley: Type of alley access
#
# LotShape: General shape of property
#
# LandContour: Flatness of the property
#
# Utilities: Type of utilities available
#
# LotConfig: Lot configuration
#
# LandSlope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits
#
# Condition1: Proximity to main road or railroad
#
# Condition2: Proximity to main road or railroad (if a second is present)
#
#
# BldgType: Type of dwelling
#
# HouseStyle: Style of dwelling
#
# OverallQual: Overall material and finish quality
#
# OverallCond: Overall condition rating
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date
#
# RoofStyle: Type of roof
#
# RoofMatl: Roof material
#
# Exterior1st: Exterior covering on house
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
# MasVnrType: Masonry veneer type
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Exterior material quality
#
# ExterCond: Present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# BsmtQual: Height of the basement
#
# BsmtCond: General condition of the basement
#
# BsmtExposure: Walkout or garden level basement walls
#
# BsmtFinType1: Quality of basement finished area
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Quality of second finished area (if present)
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# CentralAir: Central air conditioning
#
# Electrical: Electrical system
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Number of bedrooms above basement level
#
# Kitchen: Number of kitchens
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality rating
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# GarageType: Garage location
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
# GarageCond: Garage condition
#
# PavedDrive: Paved driveway
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
# Fence: Fence quality
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold
#
# YrSold: Year Sold
#
# SaleType: Type of sale
#
# SaleCondition: Condition of sale

# %%
print("Training_set_col :\n",df_train.columns)
print('No.of Col :',len(df_train.columns))
# Out:
# Training_set_col :
#  Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
numerical_feature=[]
count_int =0
for col in df_train.columns:
  if (df_train[col].dtypes != 'O') :
    count_int =count_int+1
    numerical_feature.append(col)
    print('{} :{}'.format(col ,df_train[col].dtypes))
print('\nCount_int_col :',count_int)
print('\nNumerical_feature:\n',numerical_feature)
# Out:
# Id :int64
# MSSubClass :int64
# LotFrontage :float64
# LotArea :int64
# OverallQual :int64
# OverallCond :int64
# YearBuilt :int64
# YearRemodAdd :int64
# MasVnrArea :float64
# BsmtFinSF1 :int64
# BsmtFinSF2 :int64
# BsmtUnfSF :int64
# TotalBsmtSF :int64
# 1stFlrSF :int64
# 2ndFlrSF :int64
# LowQualFinSF :int64
# GrLivArea :int64
# BsmtFullBath :int64
# BsmtHalfBath :int64
# FullBath :int64
# HalfBath :int64
# BedroomAbvGr :int64
# KitchenAbvGr :int64
# TotRmsAbvGrd :int64
# Fireplaces :int64
# GarageYrBlt :float64
# GarageCars :int64
# GarageArea :int64
# WoodDeckSF :int64
# OpenPorchSF :int64
# EnclosedPorch :int64
# 3SsnPorch :int64
# ScreenPorch :int64
# PoolArea :int64
# MiscVal :int64
# MoSold :int64
# YrSold :int64
# SalePrice :int64
#
# Count_int_col : 38
#
# Numerical_feature:
# ...

# %%
df_train[numerical_feature].head(3)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
#
# [3 rows x 38 columns]

# %%
categorical_feature=[]
count_obj =0
for col in df_train.columns:
  if (df_train[col].dtypes == object) :
    count_obj =count_obj+1
    categorical_feature.append(col)
    print('{} :{}'.format(col ,df_train[col].dtypes))
print('\nCount_obj_col :',count_obj)
print('\Categorical_feature:\n',categorical_feature)
# Out:
# MSZoning :object
# Street :object
# Alley :object
# LotShape :object
# LandContour :object
# Utilities :object
# LotConfig :object
# LandSlope :object
# Neighborhood :object
# Condition1 :object
# Condition2 :object
# BldgType :object
# HouseStyle :object
# RoofStyle :object
# RoofMatl :object
# Exterior1st :object
# Exterior2nd :object
# MasVnrType :object
# ExterQual :object
# ExterCond :object
# Foundation :object
# BsmtQual :object
# BsmtCond :object
# BsmtExposure :object
# BsmtFinType1 :object
# BsmtFinType2 :object
# Heating :object
# HeatingQC :object
# CentralAir :object
# Electrical :object
# KitchenQual :object
# Functional :object
# FireplaceQu :object
# GarageType :object
# GarageFinish :object
# GarageQual :object
# GarageCond :object
# PavedDrive :object
# PoolQC :object
# Fence :object
# MiscFeature :object
# SaleType :object
# SaleCondition :object
#
# Count_obj_col : 43
# \Categorical_feature:
# ...

# %%
df_train[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape  ... Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 1       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 2       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
# 3       RL   Pave   NaN      IR1  ...   NaN         NaN       WD       Abnorml
# 4       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df_train.describe(include=['O'])
# Out:
#        MSZoning Street Alley LotShape  ...  Fence MiscFeature SaleType SaleCondition
# count      1460   1460    91     1460  ...    281          54     1460          1460
# unique        5      2     2        4  ...      4           4        9             6
# top          RL   Pave  Grvl      Reg  ...  MnPrv        Shed       WD        Normal
# freq       1151   1454    50      925  ...    157          49     1267          1198
#
# [4 rows x 43 columns]

# %%
for col in df_train.columns:
  print('{}:\ncount_null :{} --{} \ncount_unique:{}'.format(col,df_train[col].isnull().sum(),df_train[col].dtype,len(df_train[col].unique())))
# Out:
# Id:
# count_null :0 --int64
# count_unique:1460
# MSSubClass:
# count_null :0 --int64
# count_unique:15
# MSZoning:
# count_null :0 --object
# count_unique:5
# LotFrontage:
# count_null :259 --float64
# count_unique:111
# LotArea:
# count_null :0 --int64
# count_unique:1073
# Street:
# count_null :0 --object
# count_unique:2
# Alley:
# count_null :1369 --object
# count_unique:3
# LotShape:
# count_null :0 --object
# count_unique:4
# LandContour:
# count_null :0 --object
# count_unique:4
# Utilities:
# count_null :0 --object
# count_unique:2
# LotConfig:
# count_null :0 --object
# count_unique:5
# LandSlope:
# count_null :0 --object
# count_unique:3
# Neighborhood:
# count_null :0 --object
# count_unique:25
# Condition1:
# count_null :0 --object
# count_unique:9
# Condition2:
# count_null :0 --object
# count_unique:8
# BldgType:
# count_null :0 --object
# count_unique:5
# HouseStyle:
# count_null :0 --object
# count_unique:8
# OverallQual:
# count_null :0 --int64
# count_unique:10
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
sns.heatmap(df_test.isnull(),cbar=False,yticklabels=False,cmap='Dark2_r')
plt.plot
# Out:
# <function matplotlib.pyplot.plot>

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
sns.heatmap(df_train.isnull(),cbar=False,yticklabels=False,cmap='Dark2_r')
plt.plot
# Out:
# <function matplotlib.pyplot.plot>

# %%
#columns having na
feature_na =[col for col in df_train.columns if df_train[col].isnull().sum()>1]
feature_na
#%of na in  feature_na col
for col in feature_na:
  print(col,'na %:',np.round(df_train[col].isnull().mean(),5))
# Out:
# LotFrontage na %: 0.1774
# Alley na %: 0.93767
# MasVnrType na %: 0.00548
# MasVnrArea na %: 0.00548
# BsmtQual na %: 0.02534
# BsmtCond na %: 0.02534
# BsmtExposure na %: 0.02603
# BsmtFinType1 na %: 0.02534
# BsmtFinType2 na %: 0.02603
# FireplaceQu na %: 0.4726
# GarageType na %: 0.05548
# GarageYrBlt na %: 0.05548
# GarageFinish na %: 0.05548
# GarageQual na %: 0.05548
# GarageCond na %: 0.05548
# PoolQC na %: 0.99521
# Fence na %: 0.80753
# MiscFeature na %: 0.96301

# %%
#checking how much missing affect the sale price
data =df_train.copy()
for col in feature_na:
  data[col] =np.where(data[col].isnull(),1,0)

  data.groupby(col)['SalePrice'].median().plot.bar()
  plt.title(col)
  plt.show()

# %%
#lets check for year_varibale datetime
year_feature =[col for col in df_train.columns if 'Yr' in col or 'Year' in col]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for col in year_feature:
  print(col,':',len(df_train[col].unique()),':\n',df_train[col].unique())
# Out:
# YearBuilt : 112 :
#  [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd : 61 :
#  [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# GarageYrBlt : 98 :
# ...

# %%
print('Latest_house_bulit :',df_train['YearBuilt'].max())
print('First_house_bulit :',df_train['YearBuilt'].min())
# Out:
# Latest_house_bulit : 2010
# First_house_bulit : 1872

# %%
df_train.groupby(col)['SalePrice'].median().plot()
plt.title('House_price Vs YearSold')
# Out:
# Text(0.5, 1.0, 'House_price Vs YearSold')

# %%
#the difference between year variable and year the house was sold for

for col in year_feature:
  if col !='YrSold' :
    data[col] =data['YrSold'] - data[col]
    plt.figure(figsize=(7,5))
    plt.scatter(data[col],data['SalePrice'])
    plt.title('{} Vs Salesprice'.format(col))
    plt.xlabel(col)
    plt.ylabel('SalePrice')
    plt.show()

# %%
for col in year_feature:
  diff =df_train['YrSold'] -df_train['YearBuilt']
  sns.scatterplot(diff,df_train['SalePrice'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
#in discreate and continuous features:

discrete_feature=[feature for feature in numerical_feature if len(df_train[feature].unique())<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
print('Featues having discreate(20) :',discrete_feature)
# Out:
# Featues having discreate(20) : ['MSSubClass', 'OverallQual', 'OverallCond', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea', 'MiscVal', 'MoSold']

# %%
df_train[discrete_feature].head(5)
# Out:
#    MSSubClass  OverallQual  OverallCond  ...  PoolArea  MiscVal  MoSold
# 0          60            7            5  ...         0        0       2
# 1          20            6            8  ...         0        0       5
# 2          60            7            5  ...         0        0       9
# 3          70            7            5  ...         0        0       2
# 4          60            8            5  ...         0        0      12
#
# [5 rows x 17 columns]

# %%
#relation_ship betn discrete_features and saleprice
for col in discrete_feature:
  data=df_train.copy()
  data.groupby(col)['SalePrice'].median().plot.bar()
  plt.xlabel(col)
  plt.ylabel('SalePrice')
  plt.title(col)
  plt.show()

# %%
#in  continuous features:

conti_feature=[feature for feature in numerical_feature if feature not in discrete_feature+year_feature+['Id']]
print("Continiues_varibale Count: {}".format(len(discrete_feature)))
# Out:
# Continiues_varibale Count: 17

# %%
conti_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for col in conti_feature:
    data[col].hist(bins=25)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.title(col)
    plt.show()

# %%
#in categorical features:

categorical_feature1=[feature for feature in categorical_feature if len(df_train[feature].unique())<10]
print("Categorical_feature1 Count: {}".format(len(categorical_feature1)))
# Out:
# Categorical_feature1 Count: 40

# %%
for col in categorical_feature1:
    plt.figure(figsize=(8,5))
    data[col].hist(bins=50)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.title('{} Vs Count'.format(col))
    plt.show()

# %%
for col in conti_feature:
    data=df_train.copy()
    if 0 in data[col].unique():
        pass
    else:
        data[col]=np.log(data[col])
        data.boxplot(column=col)
        plt.ylabel(col)
        plt.title(col)
        plt.show()

# %%
for col in conti_feature:
    data=df_train.copy()
    if 0 in data[col].unique():
        pass
    else:
        data[col]=np.log(data[col])
        sns.stripplot(data[col])
        plt.ylabel(col)
        plt.title(col)
        plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
for col in conti_feature:
    data=df_train.copy()
    if 0 in data[col].unique():
        pass
    else:
        sns.violinplot(data[col])
        plt.ylabel(col)
        plt.title(col)
        plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
#catogorical relation with sale price
for col in categorical_feature:
    data.groupby(col)['SalePrice'].median().plot.bar()
    plt.xlabel(col)
    plt.ylabel('SalePrice')
    plt.title('{} Vs SalePrice'.format(col))
    plt.show()

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#work with missing values
feature_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
#fill missing_values in all
for col in categorical_feature:
  df_train[col].fillna('Missing_values',inplace=True)
  df_test[col].fillna('Missing_values',inplace=True)
print('Train_nan_current:',df_train[col].isnull().sum())
print('\nTest_nan_current',df_test[col].isnull().sum())
# Out:
# Train_nan_current: 0
#
# Test_nan_current 0

# %%
numerical_feature
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
#numerical with na:
for col in numerical_feature:
  numerical_nan=[col for col in df_train.columns if df_train[col].isnull().sum()>1 and df_train[col].dtypes!='O']
numerical_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
#hadle nan in numerical col
for col in numerical_nan:
    median=df_train[col].median()
    
    ## create a new feature to capture nan values
    df_train[col+'nan']=np.where(df_train[col].isnull(),1,0)
    df_train[col].fillna(median,inplace=True)
    
df_train[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
#now replace the missing values with median or mean in numerical_features
for col in numerical_feature:
  df_train[col] =df_train[col].replace('Missing_values',df_train[col].median)

df_train[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
df_train.head(4)
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
#
# [4 rows x 84 columns]

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
#year time
for col in year_feature:
  if col != ['YrSold']:
    df_train[col]=df_train['YrSold']-df_train[col]

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea','SalePrice']

for col in num_features:
    df_train[col]=np.log(df_train[col])

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %%
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
#changing categorical values in into numerical by maping 
for col in categorical_feature:
  label=df_train.groupby([col])['SalePrice'].mean().sort_values().index
  label={k:i for i,k in enumerate(label,0)}
  df_train[col]=df_train[col].map(label)

# %%
label
# Out:
# {'Abnorml': 1,
#  'AdjLand': 0,
#  'Alloca': 3,
#  'Family': 2,
#  'Normal': 4,
#  'Partial': 5}

# %%
df_train.head(3)
# Out:
#    Id  MSSubClass  MSZoning  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1          60         3  ...               0              0               0
# 1   2          20         3  ...               0              0               0
# 2   3          60         3  ...               0              0               0
#
# [3 rows x 84 columns]

# %%
#scaling the data 
from sklearn.preprocessing import StandardScaler
Scale =StandardScaler()

# %%
scale_f =[col for col in df_train.columns if col not in ['Id','SalePrice']]

# %%
scale_f
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
len(scale_f)
# Out:
# 82

# %%
from sklearn.preprocessing import MinMaxScaler
Scale =MinMaxScaler()
Scale.fit_transform(df_train[scale_f])
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.49506375, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.47117546, ..., 0.        , 0.        ,
#         0.        ]])

# %%
df_train.head(3)
# Out:
#    Id  MSSubClass  MSZoning  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1          60         3  ...               0              0               0
# 1   2          20         3  ...               0              0               0
# 2   3          60         3  ...               0              0               0
#
# [3 rows x 84 columns]

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([df_train[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(Scale.transform(df_train[scale_f]), columns=scale_f)],
                    axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1  12.247694    0.235294  ...             0.0            0.0             0.0
# 1   2  12.109011    0.000000  ...             0.0            0.0             0.0
# 2   3  12.317167    0.235294  ...             0.0            0.0             0.0
# 3   4  11.849398    0.294118  ...             0.0            0.0             0.0
# 4   5  12.429216    0.235294  ...             0.0            0.0             0.0
#
# [5 rows x 84 columns]

# %%
#independent and dependent
X =data.iloc[:,2:]
y =data.iloc[:,1]

# %%
X.head(3)
# Out:
#    MSSubClass  MSZoning  ...  MasVnrAreanan  GarageYrBltnan
# 0    0.235294      0.75  ...            0.0             0.0
# 1    0.000000      0.75  ...            0.0             0.0
# 2    0.235294      0.75  ...            0.0             0.0
#
# [3 rows x 82 columns]

# %%
#feature  selection #lasso
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
feature_select =SelectFromModel(Lasso(alpha=0.005, random_state=0))

# %%
feature_select.fit(X,y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
feature_select.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False])

# %%
selected = X.columns[(feature_select.get_support())]
len(selected)
# Out:
# 18

# %%
selected
# Out:
# Index(['MSSubClass', 'Neighborhood', 'OverallQual', 'YearRemodAdd', 'BsmtQual',
#        'BsmtExposure', 'HeatingQC', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'BsmtFullBath', 'KitchenQual', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageCars', 'SaleCondition'],
#       dtype='object')

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.3,random_state=0)

# %%
#model fitting
from sklearn.linear_model import LinearRegression
model =LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(X_test)

# %%
y_pred =np.exp(y_pred)

# %%
y_test=np.exp(y_test)

# %%
print('model_accuracy :',model.score(X_test,y_test))
# Out:
# model_accuracy : 0.8564525070352325
